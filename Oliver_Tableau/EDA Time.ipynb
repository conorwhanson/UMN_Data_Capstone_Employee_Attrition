# %%
# Import Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("darkgrid")

# allow max columns to be displayed
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
file_path = "/Users/oliver/Documents/Bootcamp/Final_Project_Group_1/Resources/HR_Data/NEW_Clean_HRData.csv"
hr_df = pd.read_csv(file_path)
hr_df.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales             3.750
# 1   31       Yes  Travel_Frequently  Research & Development             6.250
# 2   32        No  Travel_Frequently  Research & Development            10.625
# 3   38        No         Non-Travel  Research & Development             1.250
# 4   32        No      Travel_Rarely  Research & Development             6.250
#
#    Education EducationField  EmployeeID  Gender  JobLevel  \
# 0          2  Life Sciences           1  Female         1
# 1          1  Life Sciences           2  Female         1
# 2          4          Other           3    Male         4
# 3          5  Life Sciences           4    Male         3
# 4          1        Medical           5    Male         1
#
#                      JobRole MaritalStatus  MonthlyIncome  NumCompaniesWorked  \
# ...

# %%
hr_df.Attrition.value_counts()
# Out:
# No     3605
# Yes     695
# Name: Attrition, dtype: int64

# %%
sns.displot(hr_df, x="Age", hue="Attrition", legend="full")

# %%
sns.displot(hr_df, x="BusinessTravel", hue="Attrition", legend="full")

# %%
sns.displot(hr_df, x="Department", hue="Attrition", legend="full")

# %%
sns.displot(hr_df, x="DistanceFromHome", hue="Attrition", legend="full")

# %%
sns.displot(hr_df, x="Education", hue="Attrition", legend="full")

# %%
sns.displot(hr_df, x="EducationField", hue="Attrition", legend="full")

# %%
sns.displot(hr_df, x="Gender", hue="Attrition", legend="full")

# %%
sns.displot(hr_df, x="JobLevel", hue="Attrition", legend="full")

# %%
sns.displot(hr_df, x="JobRole", hue="Attrition", legend="full")

# %%
sns.displot(hr_df, x="MaritalStatus", hue="Attrition", legend="full")

# %%
sns.displot(hr_df, x="MonthlyIncome", hue="Attrition", legend="full")

# %%
sns.displot(hr_df, x="NumCompaniesWorked", hue="Attrition", legend="full")

# %%
sns.displot(hr_df, x="StockOptionLevel", hue="Attrition", legend="full")

# %%
sns.displot(hr_df, x="WorkLifeBalance", hue="Attrition", legend="full")

# %%
sns.displot(hr_df, x="JobSatisfaction", hue="Attrition", legend="full")

# %%
sns.displot(hr_df, x="YearsWithCurrManager", hue="Attrition", legend="full")

# %%
sns.displot(hr_df, x="YearsAtCompany", hue="Attrition", legend="full")
