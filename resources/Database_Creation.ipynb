# %%
# Import Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# allow max columns to be displayed
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

from sklearn.preprocessing import StandardScaler,OneHotEncoder

# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect, func

# %%
# Files to load
employee_survey_data = "HR_Data/employee_survey_data.csv"
manager_survey_data = "HR_Data/manager_survey_data.csv"
in_time = "HR_Data/in_time.csv"
out_time = "HR_Data/out_time.csv"
general_data = "HR_Data/general_data.csv"

# %%
# Read the employee/manager survey data files and store in a Dataframe.

employee_survey_df = pd.read_csv(employee_survey_data)
manager_survey_df = pd.read_csv(manager_survey_data)
in_time_df = pd.read_csv(in_time)
out_time_df = pd.read_csv(out_time)
general_data_df = pd.read_csv(general_data)

# %%
employee_survey_df.head()
# Out:
#    EmployeeID  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance
# 0           1                      3.0              4.0              2.0
# 1           2                      3.0              2.0              4.0
# 2           3                      2.0              2.0              1.0
# 3           4                      4.0              4.0              3.0
# 4           5                      4.0              1.0              3.0

# %%
manager_survey_df.head()
# Out:
#    EmployeeID  JobInvolvement  PerformanceRating
# 0           1               3                  3
# 1           2               2                  4
# 2           3               3                  3
# 3           4               2                  3
# 4           5               3                  3

# %%
#Combine the employee and manager survey dfs inta a single df.

survey_df = pd.merge(employee_survey_df, manager_survey_df, on=["EmployeeID", "EmployeeID"])

survey_df.head()
# Out:
#    EmployeeID  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance  \
# 0           1                      3.0              4.0              2.0
# 1           2                      3.0              2.0              4.0
# 2           3                      2.0              2.0              1.0
# 3           4                      4.0              4.0              3.0
# 4           5                      4.0              1.0              3.0
#
#    JobInvolvement  PerformanceRating
# 0               3                  3
# 1               2                  4
# 2               3                  3
# 3               2                  3
# 4               3                  3

# %%
survey_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4410 entries, 0 to 4409
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   EmployeeID               4410 non-null   int64
#  1   EnvironmentSatisfaction  4385 non-null   float64
#  2   JobSatisfaction          4390 non-null   float64
#  3   WorkLifeBalance          4372 non-null   float64
#  4   JobInvolvement           4410 non-null   int64
#  5   PerformanceRating        4410 non-null   int64
# dtypes: float64(3), int64(3)
# memory usage: 241.2 KB

# %%
survey_general_df = pd.merge(survey_df, general_data_df, on=["EmployeeID", "EmployeeID"])

survey_general_df.head()
# Out:
#    EmployeeID  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance  \
# 0           1                      3.0              4.0              2.0
# 1           2                      3.0              2.0              4.0
# 2           3                      2.0              2.0              1.0
# 3           4                      4.0              4.0              3.0
# 4           5                      4.0              1.0              3.0
#
#    JobInvolvement  PerformanceRating  Age Attrition     BusinessTravel  \
# 0               3                  3   51        No      Travel_Rarely
# 1               2                  4   31       Yes  Travel_Frequently
# 2               3                  3   32        No  Travel_Frequently
# 3               2                  3   38        No         Non-Travel
# 4               3                  3   32        No      Travel_Rarely
#
#                Department  DistanceFromHome  Education EducationField  \
# 0                   Sales                 6          2  Life Sciences
# 1  Research & Development                10          1  Life Sciences
# 2  Research & Development                17          4          Other
# 3  Research & Development                 2          5  Life Sciences
# 4  Research & Development                10          1        Medical
#
#    EmployeeCount  Gender  JobLevel                    JobRole MaritalStatus  \
# 0              1  Female         1  Healthcare Representative       Married
# 1              1  Female         1         Research Scientist        Single
# 2              1    Male         4            Sales Executive       Married
# 3              1    Male         3            Human Resources       Married
# 4              1    Male         1            Sales Executive        Single
#
#    MonthlyIncome  NumCompaniesWorked Over18  PercentSalaryHike  StandardHours  \
# 0         131160                 1.0      Y                 11              8
# 1          41890                 0.0      Y                 23              8
# 2         193280                 1.0      Y                 15              8
# 3          83210                 3.0      Y                 11              8
# 4          23420                 4.0      Y                 12              8
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  YearsAtCompany  \
# 0                 0                1.0                      6               1
# 1                 1                6.0                      3               5
# 2                 3                5.0                      2               5
# 3                 3               13.0                      5               8
# 4                 2                9.0                      2               6
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                        0                     0
# 1                        1                     4
# 2                        0                     3
# 3                        7                     5
# 4                        0                     4

# %%
survey_general_df.drop('EmployeeCount', axis=1, inplace=True)

# %%
survey_general_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4410 entries, 0 to 4409
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   EmployeeID               4410 non-null   int64
#  1   EnvironmentSatisfaction  4385 non-null   float64
#  2   JobSatisfaction          4390 non-null   float64
#  3   WorkLifeBalance          4372 non-null   float64
#  4   JobInvolvement           4410 non-null   int64
#  5   PerformanceRating        4410 non-null   int64
#  6   Age                      4410 non-null   int64
#  7   Attrition                4410 non-null   object
#  8   BusinessTravel           4410 non-null   object
#  9   Department               4410 non-null   object
#  10  DistanceFromHome         4410 non-null   int64
#  11  Education                4410 non-null   int64
#  12  EducationField           4410 non-null   object
#  13  Gender                   4410 non-null   object
#  14  JobLevel                 4410 non-null   int64
#  15  JobRole                  4410 non-null   object
#  16  MaritalStatus            4410 non-null   object
#  17  MonthlyIncome            4410 non-null   int64
#  18  NumCompaniesWorked       4391 non-null   float64
#  19  Over18                   4410 non-null   object
#  20  PercentSalaryHike        4410 non-null   int64
#  21  StandardHours            4410 non-null   int64
#  22  StockOptionLevel         4410 non-null   int64
#  23  TotalWorkingYears        4401 non-null   float64
#  24  TrainingTimesLastYear    4410 non-null   int64
#  25  YearsAtCompany           4410 non-null   int64
#  26  YearsSinceLastPromotion  4410 non-null   int64
#  27  YearsWithCurrManager     4410 non-null   int64
# dtypes: float64(5), int64(15), object(8)
# memory usage: 999.1+ KB

# %%
survey_general_df.dropna(inplace=True)

# %%
survey_general_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4300 entries, 0 to 4408
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   EmployeeID               4300 non-null   int64
#  1   EnvironmentSatisfaction  4300 non-null   float64
#  2   JobSatisfaction          4300 non-null   float64
#  3   WorkLifeBalance          4300 non-null   float64
#  4   JobInvolvement           4300 non-null   int64
#  5   PerformanceRating        4300 non-null   int64
#  6   Age                      4300 non-null   int64
#  7   Attrition                4300 non-null   object
#  8   BusinessTravel           4300 non-null   object
#  9   Department               4300 non-null   object
#  10  DistanceFromHome         4300 non-null   int64
#  11  Education                4300 non-null   int64
#  12  EducationField           4300 non-null   object
#  13  Gender                   4300 non-null   object
#  14  JobLevel                 4300 non-null   int64
#  15  JobRole                  4300 non-null   object
#  16  MaritalStatus            4300 non-null   object
#  17  MonthlyIncome            4300 non-null   int64
#  18  NumCompaniesWorked       4300 non-null   float64
#  19  Over18                   4300 non-null   object
#  20  PercentSalaryHike        4300 non-null   int64
#  21  StandardHours            4300 non-null   int64
#  22  StockOptionLevel         4300 non-null   int64
#  23  TotalWorkingYears        4300 non-null   float64
#  24  TrainingTimesLastYear    4300 non-null   int64
#  25  YearsAtCompany           4300 non-null   int64
#  26  YearsSinceLastPromotion  4300 non-null   int64
#  27  YearsWithCurrManager     4300 non-null   int64
# dtypes: float64(5), int64(15), object(8)
# memory usage: 974.2+ KB

# %%
in_time_df.dtypes
# Out:
# Unnamed: 0      int64
# 2015-01-01    float64
# 2015-01-02     object
# 2015-01-05     object
# 2015-01-06     object
#                ...
# 2015-12-25    float64
# 2015-12-28     object
# 2015-12-29     object
# 2015-12-30     object
# 2015-12-31     object
# Length: 262, dtype: object

# %%
survey_general_df["MonthlyIncome"] = survey_general_df["MonthlyIncome"].apply(lambda x : x * 0.013)
survey_general_df.head()
# Out:
#    EmployeeID  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance  \
# 0           1                      3.0              4.0              2.0
# 1           2                      3.0              2.0              4.0
# 2           3                      2.0              2.0              1.0
# 3           4                      4.0              4.0              3.0
# 4           5                      4.0              1.0              3.0
#
#    JobInvolvement  PerformanceRating  Age Attrition     BusinessTravel  \
# 0               3                  3   51        No      Travel_Rarely
# 1               2                  4   31       Yes  Travel_Frequently
# 2               3                  3   32        No  Travel_Frequently
# 3               2                  3   38        No         Non-Travel
# 4               3                  3   32        No      Travel_Rarely
#
#                Department  DistanceFromHome  Education EducationField  Gender  \
# 0                   Sales                 6          2  Life Sciences  Female
# 1  Research & Development                10          1  Life Sciences  Female
# 2  Research & Development                17          4          Other    Male
# 3  Research & Development                 2          5  Life Sciences    Male
# 4  Research & Development                10          1        Medical    Male
#
#    JobLevel                    JobRole MaritalStatus  MonthlyIncome  \
# 0         1  Healthcare Representative       Married        1705.08
# 1         1         Research Scientist        Single         544.57
# 2         4            Sales Executive       Married        2512.64
# 3         3            Human Resources       Married        1081.73
# 4         1            Sales Executive        Single         304.46
#
#    NumCompaniesWorked Over18  PercentSalaryHike  StandardHours  \
# 0                 1.0      Y                 11              8
# 1                 0.0      Y                 23              8
# 2                 1.0      Y                 15              8
# 3                 3.0      Y                 11              8
# 4                 4.0      Y                 12              8
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  YearsAtCompany  \
# 0                 0                1.0                      6               1
# 1                 1                6.0                      3               5
# 2                 3                5.0                      2               5
# 3                 3               13.0                      5               8
# 4                 2                9.0                      2               6
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                        0                     0
# 1                        1                     4
# 2                        0                     3
# 3                        7                     5
# 4                        0                     4

# %%
survey_general_df["DistanceFromHome"] = survey_general_df["DistanceFromHome"].apply(lambda x : x / 1.6)
survey_general_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4300 entries, 0 to 4408
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   EmployeeID               4300 non-null   int64
#  1   EnvironmentSatisfaction  4300 non-null   float64
#  2   JobSatisfaction          4300 non-null   float64
#  3   WorkLifeBalance          4300 non-null   float64
#  4   JobInvolvement           4300 non-null   int64
#  5   PerformanceRating        4300 non-null   int64
#  6   Age                      4300 non-null   int64
#  7   Attrition                4300 non-null   object
#  8   BusinessTravel           4300 non-null   object
#  9   Department               4300 non-null   object
#  10  DistanceFromHome         4300 non-null   float64
#  11  Education                4300 non-null   int64
#  12  EducationField           4300 non-null   object
#  13  Gender                   4300 non-null   object
#  14  JobLevel                 4300 non-null   int64
#  15  JobRole                  4300 non-null   object
#  16  MaritalStatus            4300 non-null   object
#  17  MonthlyIncome            4300 non-null   float64
#  18  NumCompaniesWorked       4300 non-null   float64
#  19  Over18                   4300 non-null   object
#  20  PercentSalaryHike        4300 non-null   int64
#  21  StandardHours            4300 non-null   int64
#  22  StockOptionLevel         4300 non-null   int64
#  23  TotalWorkingYears        4300 non-null   float64
#  24  TrainingTimesLastYear    4300 non-null   int64
#  25  YearsAtCompany           4300 non-null   int64
#  26  YearsSinceLastPromotion  4300 non-null   int64
#  27  YearsWithCurrManager     4300 non-null   int64
# dtypes: float64(7), int64(13), object(8)
# memory usage: 974.2+ KB

# %%
# Save as a new CSV

survey_general_df.to_csv("Clean_HRData.csv")

# %%
# OneHotEncoder

attrition_cat = survey_general_df.dtypes[survey_general_df.dtypes == 'object'].index.to_list()
survey_general_df[attrition_cat].nunique()
# Out:
# Attrition         2
# BusinessTravel    3
# Department        3
# EducationField    6
# Gender            2
# JobRole           9
# MaritalStatus     3
# Over18            1
# dtype: int64

# %%
# OneHotEncode cat data
enc = OneHotEncoder(sparse=False)

# Fit & transform the enc using the cat list
encode_df = pd.DataFrame(enc.fit_transform(survey_general_df[attrition_cat]))

# Add encoded vars to DF
encode_df.columns = enc.get_feature_names_out(attrition_cat)
encode_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4300 entries, 0 to 4299
# Data columns (total 29 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Attrition_No                       4300 non-null   float64
#  1   Attrition_Yes                      4300 non-null   float64
#  2   BusinessTravel_Non-Travel          4300 non-null   float64
#  3   BusinessTravel_Travel_Frequently   4300 non-null   float64
#  4   BusinessTravel_Travel_Rarely       4300 non-null   float64
#  5   Department_Human Resources         4300 non-null   float64
#  6   Department_Research & Development  4300 non-null   float64
#  7   Department_Sales                   4300 non-null   float64
#  8   EducationField_Human Resources     4300 non-null   float64
#  9   EducationField_Life Sciences       4300 non-null   float64
#  10  EducationField_Marketing           4300 non-null   float64
#  11  EducationField_Medical             4300 non-null   float64
#  12  EducationField_Other               4300 non-null   float64
#  13  EducationField_Technical Degree    4300 non-null   float64
#  14  Gender_Female                      4300 non-null   float64
#  15  Gender_Male                        4300 non-null   float64
#  16  JobRole_Healthcare Representative  4300 non-null   float64
#  17  JobRole_Human Resources            4300 non-null   float64
#  18  JobRole_Laboratory Technician      4300 non-null   float64
#  19  JobRole_Manager                    4300 non-null   float64
#  20  JobRole_Manufacturing Director     4300 non-null   float64
#  21  JobRole_Research Director          4300 non-null   float64
#  22  JobRole_Research Scientist         4300 non-null   float64
#  23  JobRole_Sales Executive            4300 non-null   float64
#  24  JobRole_Sales Representative       4300 non-null   float64
#  25  MaritalStatus_Divorced             4300 non-null   float64
#  26  MaritalStatus_Married              4300 non-null   float64
#  27  MaritalStatus_Single               4300 non-null   float64
#  28  Over18_Y                           4300 non-null   float64
# dtypes: float64(29)
# memory usage: 974.3 KB

# %%
# Merge the encoded dataframe with the OG dataframe, then drop the categorical columns
hr_df = survey_general_df.merge(encode_df, how="inner", left_index=True, right_index=True)
hr_df = hr_df.drop(attrition_cat, 1)
hr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4195 entries, 0 to 4299
# Data columns (total 49 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   EmployeeID                         4195 non-null   int64
#  1   EnvironmentSatisfaction            4195 non-null   float64
#  2   JobSatisfaction                    4195 non-null   float64
#  3   WorkLifeBalance                    4195 non-null   float64
#  4   JobInvolvement                     4195 non-null   int64
#  5   PerformanceRating                  4195 non-null   int64
#  6   Age                                4195 non-null   int64
#  7   DistanceFromHome                   4195 non-null   float64
#  8   Education                          4195 non-null   int64
#  9   JobLevel                           4195 non-null   int64
#  10  MonthlyIncome                      4195 non-null   float64
#  11  NumCompaniesWorked                 4195 non-null   float64
#  12  PercentSalaryHike                  4195 non-null   int64
#  13  StandardHours                      4195 non-null   int64
#  14  StockOptionLevel                   4195 non-null   int64
#  15  TotalWorkingYears                  4195 non-null   float64
#  16  TrainingTimesLastYear              4195 non-null   int64
#  17  YearsAtCompany                     4195 non-null   int64
#  18  YearsSinceLastPromotion            4195 non-null   int64
#  19  YearsWithCurrManager               4195 non-null   int64
#  20  Attrition_No                       4195 non-null   float64
#  21  Attrition_Yes                      4195 non-null   float64
#  22  BusinessTravel_Non-Travel          4195 non-null   float64
#  23  BusinessTravel_Travel_Frequently   4195 non-null   float64
#  24  BusinessTravel_Travel_Rarely       4195 non-null   float64
#  25  Department_Human Resources         4195 non-null   float64
#  26  Department_Research & Development  4195 non-null   float64
#  27  Department_Sales                   4195 non-null   float64
#  28  EducationField_Human Resources     4195 non-null   float64
#  29  EducationField_Life Sciences       4195 non-null   float64
#  30  EducationField_Marketing           4195 non-null   float64
#  31  EducationField_Medical             4195 non-null   float64
#  32  EducationField_Other               4195 non-null   float64
#  33  EducationField_Technical Degree    4195 non-null   float64
#  34  Gender_Female                      4195 non-null   float64
#  35  Gender_Male                        4195 non-null   float64
#  36  JobRole_Healthcare Representative  4195 non-null   float64
#  37  JobRole_Human Resources            4195 non-null   float64
#  38  JobRole_Laboratory Technician      4195 non-null   float64
#  39  JobRole_Manager                    4195 non-null   float64
#  40  JobRole_Manufacturing Director     4195 non-null   float64
#  41  JobRole_Research Director          4195 non-null   float64
#  42  JobRole_Research Scientist         4195 non-null   float64
#  43  JobRole_Sales Executive            4195 non-null   float64
#  44  JobRole_Sales Representative       4195 non-null   float64
#  45  MaritalStatus_Divorced             4195 non-null   float64
#  46  MaritalStatus_Married              4195 non-null   float64
#  47  MaritalStatus_Single               4195 non-null   float64
#  48  Over18_Y                           4195 non-null   float64
# dtypes: float64(36), int64(13)
# memory usage: 1.6 MB
# C:\Users\pmino\AppData\Local\Temp\ipykernel_24008\408510147.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   hr_df = hr_df.drop(attrition_cat, 1)

# %%
hr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4195 entries, 0 to 4299
# Data columns (total 49 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   EmployeeID                         4195 non-null   int64
#  1   EnvironmentSatisfaction            4195 non-null   float64
#  2   JobSatisfaction                    4195 non-null   float64
#  3   WorkLifeBalance                    4195 non-null   float64
#  4   JobInvolvement                     4195 non-null   int64
#  5   PerformanceRating                  4195 non-null   int64
#  6   Age                                4195 non-null   int64
#  7   DistanceFromHome                   4195 non-null   float64
#  8   Education                          4195 non-null   int64
#  9   JobLevel                           4195 non-null   int64
#  10  MonthlyIncome                      4195 non-null   float64
#  11  NumCompaniesWorked                 4195 non-null   float64
#  12  PercentSalaryHike                  4195 non-null   int64
#  13  StandardHours                      4195 non-null   int64
#  14  StockOptionLevel                   4195 non-null   int64
#  15  TotalWorkingYears                  4195 non-null   float64
#  16  TrainingTimesLastYear              4195 non-null   int64
#  17  YearsAtCompany                     4195 non-null   int64
#  18  YearsSinceLastPromotion            4195 non-null   int64
#  19  YearsWithCurrManager               4195 non-null   int64
#  20  Attrition_No                       4195 non-null   float64
#  21  Attrition_Yes                      4195 non-null   float64
#  22  BusinessTravel_Non-Travel          4195 non-null   float64
#  23  BusinessTravel_Travel_Frequently   4195 non-null   float64
#  24  BusinessTravel_Travel_Rarely       4195 non-null   float64
#  25  Department_Human Resources         4195 non-null   float64
#  26  Department_Research & Development  4195 non-null   float64
#  27  Department_Sales                   4195 non-null   float64
#  28  EducationField_Human Resources     4195 non-null   float64
#  29  EducationField_Life Sciences       4195 non-null   float64
#  30  EducationField_Marketing           4195 non-null   float64
#  31  EducationField_Medical             4195 non-null   float64
#  32  EducationField_Other               4195 non-null   float64
#  33  EducationField_Technical Degree    4195 non-null   float64
#  34  Gender_Female                      4195 non-null   float64
#  35  Gender_Male                        4195 non-null   float64
#  36  JobRole_Healthcare Representative  4195 non-null   float64
#  37  JobRole_Human Resources            4195 non-null   float64
#  38  JobRole_Laboratory Technician      4195 non-null   float64
#  39  JobRole_Manager                    4195 non-null   float64
#  40  JobRole_Manufacturing Director     4195 non-null   float64
#  41  JobRole_Research Director          4195 non-null   float64
#  42  JobRole_Research Scientist         4195 non-null   float64
#  43  JobRole_Sales Executive            4195 non-null   float64
#  44  JobRole_Sales Representative       4195 non-null   float64
#  45  MaritalStatus_Divorced             4195 non-null   float64
#  46  MaritalStatus_Married              4195 non-null   float64
#  47  MaritalStatus_Single               4195 non-null   float64
#  48  Over18_Y                           4195 non-null   float64
# dtypes: float64(36), int64(13)
# memory usage: 1.6 MB

# %%
hr_df.to_csv("Clean_HRData_ML.csv")
