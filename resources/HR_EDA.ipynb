# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
hr_df = pd.read_csv("HR_Data/Clean_HRData.csv")
hr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4300 entries, 0 to 4299
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               4300 non-null   int64
#  1   Age                      4300 non-null   int64
#  2   Attrition                4300 non-null   object
#  3   BusinessTravel           4300 non-null   object
#  4   Department               4300 non-null   object
#  5   DistanceFromHome         4300 non-null   float64
#  6   Education                4300 non-null   int64
#  7   EducationField           4300 non-null   object
#  8   EmployeeID               4300 non-null   int64
#  9   Gender                   4300 non-null   object
#  10  JobLevel                 4300 non-null   int64
#  11  JobRole                  4300 non-null   object
#  12  MaritalStatus            4300 non-null   object
#  13  MonthlyIncome            4300 non-null   float64
#  14  NumCompaniesWorked       4300 non-null   float64
#  15  PercentSalaryHike        4300 non-null   int64
#  16  StandardHours            4300 non-null   int64
#  17  StockOptionLevel         4300 non-null   int64
#  18  TotalWorkingYears        4300 non-null   float64
#  19  TrainingTimesLastYear    4300 non-null   int64
#  20  YearsAtCompany           4300 non-null   int64
#  21  YearsSinceLastPromotion  4300 non-null   int64
#  22  YearsWithCurrManager     4300 non-null   int64
#  23  EnvironmentSatisfaction  4300 non-null   float64
#  24  JobSatisfaction          4300 non-null   float64
#  25  WorkLifeBalance          4300 non-null   float64
#  26  JobInvolvement           4300 non-null   int64
#  27  PerformanceRating        4300 non-null   int64
# dtypes: float64(7), int64(14), object(7)
# memory usage: 940.8+ KB

# %%
hr_df.head()
# Out:
#    Unnamed: 0  Age Attrition     BusinessTravel              Department  \
# 0           0   51        No      Travel_Rarely                   Sales
# 1           1   31       Yes  Travel_Frequently  Research & Development
# 2           2   32        No  Travel_Frequently  Research & Development
# 3           3   38        No         Non-Travel  Research & Development
# 4           4   32        No      Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeID  Gender  JobLevel  \
# 0             3.750          2  Life Sciences           1  Female         1
# 1             6.250          1  Life Sciences           2  Female         1
# 2            10.625          4          Other           3    Male         4
# 3             1.250          5  Life Sciences           4    Male         3
# 4             6.250          1        Medical           5    Male         1
#
#                      JobRole MaritalStatus  MonthlyIncome  NumCompaniesWorked  \
# 0  Healthcare Representative       Married        1705.08                 1.0
# 1         Research Scientist        Single         544.57                 0.0
# 2            Sales Executive       Married        2512.64                 1.0
# 3            Human Resources       Married        1081.73                 3.0
# 4            Sales Executive        Single         304.46                 4.0
#
#    PercentSalaryHike  StandardHours  StockOptionLevel  TotalWorkingYears  \
# 0                 11              8                 0                1.0
# 1                 23              8                 1                6.0
# 2                 15              8                 3                5.0
# 3                 11              8                 3               13.0
# 4                 12              8                 2                9.0
#
#    TrainingTimesLastYear  YearsAtCompany  YearsSinceLastPromotion  \
# 0                      6               1                        0
# 1                      3               5                        1
# 2                      2               5                        0
# 3                      5               8                        7
# 4                      2               6                        0
#
#    YearsWithCurrManager  EnvironmentSatisfaction  JobSatisfaction  \
# 0                     0                      3.0              4.0
# 1                     4                      3.0              2.0
# 2                     3                      2.0              2.0
# 3                     5                      4.0              4.0
# 4                     4                      4.0              1.0
#
#    WorkLifeBalance  JobInvolvement  PerformanceRating
# 0              2.0               3                  3
# 1              4.0               2                  4
# 2              1.0               3                  3
# 3              3.0               2                  3
# 4              3.0               3                  3

# %%
hr_df.MonthlyIncome.describe()
# Out:
# count    4300.000000
# mean      845.777974
# std       611.590186
# min       131.170000
# 25%       380.380000
# 50%       641.680000
# 75%      1089.432500
# max      2599.870000
# Name: MonthlyIncome, dtype: float64

# %%
sns.catplot(y="MonthlyIncome", kind="box", data=hr_df)

# %%
sns.displot(hr_df, x="MonthlyIncome", kde=True)

# %%
sns.displot(hr_df, x="Gender", hue="MaritalStatus", legend="full")

# %%
sns.displot(hr_df, x="Gender", y="MonthlyIncome")

# %%
Ed = sns.displot(hr_df, x="EducationField")
Ed.set_xticklabels(rotation=45, horizontalalignment='right')

# %%
sns.displot(hr_df, x="BusinessTravel")

# %%
sns.displot(hr_df, x="DistanceFromHome", kind="ecdf")

# %%
job_dept = sns.displot(hr_df, x="JobRole", hue="Department")
job_dept.set_xticklabels(rotation=45, horizontalalignment='right')

# %%
dept_attr = sns.displot(hr_df, x='Department', hue='Attrition')
dept_attr.set_xticklabels(rotation=45, horizontalalignment='right')

# %%
sns.displot(hr_df, x="JobSatisfaction")

# %%
job_dep = sns.displot(hr_df, x="Department", hue="JobRole", multiple="dodge")
job_dep.set_xticklabels(rotation=45, horizontalalignment='right')

# %%
sns.displot(hr_df, x='StockOptionLevel')
