# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
hr_df = pd.read_csv("HR_Data/NEW_Clean_HRData.csv")
hr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4300 entries, 0 to 4299
# Data columns (total 27 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      4300 non-null   int64
#  1   Attrition                4300 non-null   object
#  2   BusinessTravel           4300 non-null   object
#  3   Department               4300 non-null   object
#  4   DistanceFromHome         4300 non-null   float64
#  5   Education                4300 non-null   int64
#  6   EducationField           4300 non-null   object
#  7   EmployeeID               4300 non-null   int64
#  8   Gender                   4300 non-null   object
#  9   JobLevel                 4300 non-null   int64
#  10  JobRole                  4300 non-null   object
#  11  MaritalStatus            4300 non-null   object
#  12  MonthlyIncome            4300 non-null   float64
#  13  NumCompaniesWorked       4300 non-null   float64
# ...

# %%
hr_df.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales             3.750
# 1   31       Yes  Travel_Frequently  Research & Development             6.250
# 2   32        No  Travel_Frequently  Research & Development            10.625
# 3   38        No         Non-Travel  Research & Development             1.250
# 4   32        No      Travel_Rarely  Research & Development             6.250
#
#    Education EducationField  EmployeeID  Gender  JobLevel  \
# 0          2  Life Sciences           1  Female         1
# 1          1  Life Sciences           2  Female         1
# 2          4          Other           3    Male         4
# 3          5  Life Sciences           4    Male         3
# 4          1        Medical           5    Male         1
#
#                      JobRole MaritalStatus  MonthlyIncome  NumCompaniesWorked  \
# ...

# %%
hr_df.MonthlyIncome.describe()
# Out:
# count    4300.000000
# mean      845.777974
# std       611.590186
# min       131.170000
# 25%       380.380000
# 50%       641.680000
# 75%      1089.432500
# max      2599.870000
# Name: MonthlyIncome, dtype: float64

# %%
hr_df.DistanceFromHome.describe()
# Out:
# count    4300.000000
# mean        5.748692
# std         5.060662
# min         0.625000
# 25%         1.250000
# 50%         4.375000
# 75%         8.750000
# max        18.125000
# Name: DistanceFromHome, dtype: float64

# %%
colors = ["#A2C5AC","#7F6A93","#878E99","#9DB5B2","#3C3E3C"]
fig, ax = plt.subplots(figsize=(8,20))
sns.set_palette(sns.color_palette(colors))
sns.boxplot(ax=ax, data=hr_df, y="MonthlyIncome")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20,10))
sns.set_palette(sns.color_palette(colors))
sns.histplot(ax=ax, data=hr_df, x="MonthlyIncome", kde=True)
plt.show()

# %%
sns.set_palette(sns.color_palette(colors))
fig, ax = plt.subplots(figsize=(10,6))
sns.histplot(ax=ax,data=hr_df, x="Gender", hue="MaritalStatus", multiple="stack")
plt.show()

# %%
sns.histplot(hr_df, x="Gender", hue="Gender", y="MonthlyIncome")
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='MonthlyIncome'>

# %%
colors = ["#A2C5AC","#7F6A93","#3C3E3C","#878E99","#9DB5B2"]
sns.set_palette(sns.color_palette(colors))
fig, ax = plt.subplots(figsize=(10,6))
sns.histplot(ax=ax, data=hr_df, x="EducationField", hue="EducationField")
plt.show()

# %%
colors = ["#A2C5AC","#7F6A93","#3C3E3C","#878E99","#9DB5B2"]
sns.set_palette(sns.color_palette(colors))
fig, ax = plt.subplots(figsize=(10,6))
sns.histplot(hr_df, x="BusinessTravel", hue="BusinessTravel")
# Out:
# <AxesSubplot:xlabel='BusinessTravel', ylabel='Count'>

# %%
colors = ["#A2C5AC","#7F6A93","#3C3E3C","#878E99","#9DB5B2"]
sns.set_palette(sns.color_palette(colors))
fig, ax = plt.subplots(figsize=(10,6))
sns.ecdfplot(ax=ax, data=hr_df, x="DistanceFromHome")
plt.show()

# %%
colors = ["#A2C5AC","#7F6A93","#3C3E3C","#878E99","#9DB5B2"]
sns.set_palette(sns.color_palette(colors))
fig, ax = plt.subplots(figsize=(10,6))
sns.histplot(ax=ax, data=hr_df, x="JobRole", hue="Department")
ax.get_xticklabels()

for label in ax.get_xticklabels():
    label.set_rotation(45)

# %%
colors = ["#A2C5AC","#3C3E3C"]


sns.set_palette(sns.color_palette(palette=colors))
fig, ax = plt.subplots(figsize=(10,6))
sns.histplot(ax=ax, data=hr_df, x='Department', hue='Attrition')
ax.get_xticklabels()

for label in ax.get_xticklabels():
    label.set_rotation(45)

# %%
colors1 = ["#A2C5AC"]
sns.set_palette(sns.color_palette(palette=colors1))
fig, ax = plt.subplots(figsize=(10,6))
sns.histplot(ax=ax, data=hr_df, x="JobSatisfaction")
ax.get_xticklabels()
# Out:
# [Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, '')]

# %%
colors3 = ["#A2C5AC","#7F6A93","#3C3E3C","#878E99","#9DB5B2"]
sns.set_palette(sns.color_palette(colors3))
fig, ax = plt.subplots(figsize=(10,6))
sns.histplot(ax=ax, data=hr_df, x="Department", hue="JobRole")
ax.get_xticklabels()

for label in ax.get_xticklabels():
    label.set_rotation(45)

# %%
colors_p = ["#7F6A93"]
sns.set_palette(sns.color_palette(palette=colors_p))
fig, ax = plt.subplots(figsize=(10,6))
sns.histplot(ax=ax, data=hr_df, x="StockOptionLevel")
ax.get_xticklabels()
# Out:
# [Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, '')]

# %%
colors_v = ["#A2C5AC","#7F6A93","#3C3E3C","#878E99","#9DB5B2"]
sns.set_palette(sns.color_palette(palette=colors_v))
sns.catplot(x="MonthlyIncome",y='Department', hue="Attrition",
            kind="violin", split=True, data=hr_df)

# %%
colors_v = ["#A2C5AC","#7F6A93","#3C3E3C","#878E99","#9DB5B2"]
sns.set_palette(sns.color_palette(palette=colors_v))
sns.catplot(x="MonthlyIncome",y='JobRole', hue="Attrition",
            kind="violin", split=True, data=hr_df)

# %%
colors_v = ["#A2C5AC","#7F6A93","#3C3E3C","#878E99","#9DB5B2"]
sns.set_palette(sns.color_palette(palette=colors_v))
sns.catplot(x="PercentSalaryHike",y='JobRole', hue="Attrition",
            kind="violin", split=True, data=hr_df)
